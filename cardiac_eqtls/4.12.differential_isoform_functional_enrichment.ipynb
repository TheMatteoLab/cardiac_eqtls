# %%
setwd("/frazer01/projects/CARDIPS/analysis/cardiac_eqtls")

source("script/packages.R"  )
source("script/input_data.R")
source("script/functions.R" )

dir.create("pipeline/4.1.differential_expression", showWarnings = FALSE)

# %% [markdown]
# # Input data

# %%
metadata   =              fread("pipeline/3.1.covariates/metadata.txt"     , sep = "\t", header = TRUE , data.table = FALSE)
covariates = add_rownames(fread("pipeline/3.1.covariates/covariates.txt"   , sep = "\t", header = TRUE , data.table = FALSE))
int_list   = readLines         ("pipeline/3.2.eqtls/vars/cardiac_eqtls.txt")
#int_list   = int_list[grepl("^peer", int_list) == FALSE & grepl("^pc", int_list) == FALSE] # original
int_list   = c("sex", "total_reads_norm") # remove mitochondrial reads as covariate
covariates = covariates[,int_list]
gene_tpm   = add_rownames(fread("pipeline/1.2.expression/tpm_gene.normalized.txt"   , sep = "\t", header = TRUE , data.table = FALSE))
isof_tpm   = add_rownames(fread("pipeline/1.2.expression/tpm_isoform.normalized.txt", sep = "\t", header = TRUE , data.table = FALSE))
isof_use   = add_rownames(fread("pipeline/1.2.expression/use_isoform.normalized.txt", sep = "\t", header = TRUE , data.table = FALSE))

# %%
gene_info               = fread("input/phenotypes/gene_info.txt"   , sep = "\t", header = TRUE, data.table = FALSE)
isof_info               = fread("input/phenotypes/isoform_info.txt", sep = "\t", header = TRUE, data.table = FALSE)
gene_info$transcript_id = gene_info$gene_id

diffgene = fread(paste("pipeline/4.1.differential_expression", "diffexp.txt"     , sep = "/"), sep = "\t", header = TRUE, data.table = FALSE)
diffcell = fread(paste("pipeline/4.1.differential_expression", "diffexp_cell.txt", sep = "/"), sep = "\t", header = TRUE, data.table = FALSE)

diffgene$diffexp = FALSE
diffgene[diffgene$qval < 0.05, "diffexp"] = TRUE

# %% [markdown]
# # Get gene sets

# %%
gmt2list = function(gs)
{    
    indata = readLines(paste("input/phenotypes/msigdb", paste(gs, "v7.1.symbols.gmt", sep = "."), sep = "/"))
    indata = lapply(indata, function(x)
    {
        this = unlist(strsplit(x, "\t"))
        out  = list(gene_set = this[[1]], url = this[[2]], gene_names = this[3:length(this)])
        
        return(out)
    })
    names(indata) = unlist(lapply(indata, function(x){x$gene_set}))
    
    return(indata)
}

msigdb               = c("c2.cp.biocarta", "c2.cp.kegg", "c2.cp.reactome", "c5.bp", "c5.cc", "c5.mf", "h.all")
#msigdb               = c("h.all")
genesets2test        = lapply(msigdb, gmt2list)
names(genesets2test) = msigdb

# %% [markdown]
# # Functional enrichment

# %%
calculate_functional_enrichment_tissue_by_gene_set = function(tissue1, tissue2, type, gs, gene_set, diffexp, genes_dif, genes_ns)
{
    genes_in   = intersect(gene_set[["gene_names"]], c(genes_dif, genes_ns))
    out        = data.frame(tissue1 = tissue1, tissue2 = tissue2, type = type, gs_source = gs, gene_set = gene_set[["gene_set"]], url = gene_set[["url"]], ngenes = length(genes_in))
    
    if(nrow(diffexp[diffexp$gene_name %in% genes_in,]) > 1)
    {
        tofisher = matrix(0, nrow = 2, ncol = 2)
        rownames(tofisher) = c("dif", "ns")
        colnames(tofisher) = c("yes", "no")

        tofisher["dif" , "yes"] =                     length(intersect(genes_dif, genes_in))
        tofisher["dif" , "no" ] = length(genes_dif) - length(intersect(genes_dif, genes_in))
        tofisher["ns"  , "yes"] =                     length(intersect(genes_ns , genes_in))
        tofisher["ns"  , "no" ] = length(genes_ns ) - length(intersect(genes_ns , genes_in))

        test = fisher.test(tofisher)

        out  = cbind(out, data.frame(dif_yes  = tofisher["dif" , "yes"],
                                     dif_no   = tofisher["dif" , "no" ],
                                     ns_yes   = tofisher["ns"  , "yes"],
                                     ns_no    = tofisher["ns"  , "no" ],
                                     estimate = test$estimate, 
                                     ci1      = test$conf.int[[1]], 
                                     ci2      = test$conf.int[[2]], 
                                     pval     = test$p.value))
    }else
    {
        out  = cbind(out, data.frame(dif_yes  = NA,
                                     dif_no   = NA,
                                     ns_yes   = NA,
                                     ns_no    = NA,
                                     estimate = NA,
                                     ci1      = NA,
                                     ci2      = NA,
                                     pval     = NA
                                    ))

    }
    return(out)
}

run_test = function(tissue1, tissue2, type, gs, gene_set, diffgene)
{
    diffexp    = diffgene[diffgene$type == type & diffgene$tissue1 == tissue1 & diffgene$tissue2 == tissue2,]
    genes_dif  = unique(diffexp[diffexp$qval < 0.05 & abs(diffexp$beta) > 2, "gene_name"])
    genes_ns   = unique(diffexp[!diffexp$gene_name %in% genes_dif          , "gene_name"])

    return(calculate_functional_enrichment_tissue_by_gene_set(tissue1, tissue2, type, gs, gene_set, diffexp, genes_dif, genes_ns))
}

type      = "isoform_use"
#gs        = "c2.cp.biocarta"
#gene_sets = genesets2test[[gs]]
#gene_set  = gene_sets[[1]]
#tissue1   = "ipsc_cvpc"
#tissue2   = "heart"

tests = as.data.frame(rbindlist(lapply(msigdb, function(gs)
{
    message(paste(type, gs))
    gene_sets = genesets2test[[gs]]
    as.data.frame(rbindlist(lapply(gene_sets, function(gene_set)
    {
        out = rbind(run_test("ipsc_cvpc", "heart"  , type, gs, gene_set, diffgene),
                    run_test("ipsc_cvpc", "arteria", type, gs, gene_set, diffgene),
                    run_test("heart"    , "arteria", type, gs, gene_set, diffgene)
                   )
            return(out)
        run_test(tissue1, tissue2, type, gs, gene_set, diffexp, genes_dif, genes_ns)
    })), stringsAsFactors = FALSE)
})), stringsAsFactors = FALSE)

tests     = tests[is.na(tests$estimate) == FALSE, ]
tests$fdr = p.adjust(tests$pval, method = "BH")

fwrite(tests, "pipeline/4.1.differential_expression/functional_enrichment_isoforms.tissue.txt", sep = "\t", col.names = TRUE, row.names = FALSE)
# Out:
# isoform_use c2.cp.biocarta
#
# isoform_use c2.cp.kegg
#
# isoform_use c2.cp.reactome
#
# isoform_use c5.bp
#
# isoform_use c5.cc
#
# isoform_use c5.mf
#
# isoform_use h.all

# %%
tests
# Out:
#       tissue1   tissue2 type        gs_source
# 1     ipsc_cvpc heart   isoform_use c2.cp.biocarta
# 2     ipsc_cvpc arteria isoform_use c2.cp.biocarta
# 3     heart     arteria isoform_use c2.cp.biocarta
# 4     ipsc_cvpc heart   isoform_use c2.cp.biocarta
# 5     ipsc_cvpc arteria isoform_use c2.cp.biocarta
# 6     heart     arteria isoform_use c2.cp.biocarta
# 7     ipsc_cvpc heart   isoform_use c2.cp.biocarta
# 8     ipsc_cvpc arteria isoform_use c2.cp.biocarta
# 9     heart     arteria isoform_use c2.cp.biocarta
# 10    ipsc_cvpc heart   isoform_use c2.cp.biocarta
# 11    ipsc_cvpc arteria isoform_use c2.cp.biocarta
# 12    heart     arteria isoform_use c2.cp.biocarta
# 13    ipsc_cvpc heart   isoform_use c2.cp.biocarta
# 14    ipsc_cvpc arteria isoform_use c2.cp.biocarta
# 15    heart     arteria isoform_use c2.cp.biocarta
# 16    ipsc_cvpc heart   isoform_use c2.cp.biocarta
# 17    ipsc_cvpc arteria isoform_use c2.cp.biocarta
# 18    heart     arteria isoform_use c2.cp.biocarta
# 19    ipsc_cvpc heart   isoform_use c2.cp.biocarta
# 20    ipsc_cvpc arteria isoform_use c2.cp.biocarta
# 21    heart     arteria isoform_use c2.cp.biocarta
# 22    ipsc_cvpc heart   isoform_use c2.cp.biocarta
# 23    ipsc_cvpc arteria isoform_use c2.cp.biocarta
# 24    heart     arteria isoform_use c2.cp.biocarta
# 25    ipsc_cvpc heart   isoform_use c2.cp.biocarta
# 26    ipsc_cvpc arteria isoform_use c2.cp.biocarta
# 27    heart     arteria isoform_use c2.cp.biocarta
# 28    ipsc_cvpc heart   isoform_use c2.cp.biocarta
# 29    ipsc_cvpc arteria isoform_use c2.cp.biocarta
# 30    heart     arteria isoform_use c2.cp.biocarta
# ⋮     ⋮         ⋮       ⋮           ⋮
# 36718 ipsc_cvpc heart   isoform_use h.all
# 36719 ipsc_cvpc arteria isoform_use h.all
# 36720 heart     arteria isoform_use h.all
# 36721 ipsc_cvpc heart   isoform_use h.all
# 36722 ipsc_cvpc arteria isoform_use h.all
# 36723 heart     arteria isoform_use h.all
# 36724 ipsc_cvpc heart   isoform_use h.all
# 36725 ipsc_cvpc arteria isoform_use h.all
# 36726 heart     arteria isoform_use h.all
# 36727 ipsc_cvpc heart   isoform_use h.all
# 36728 ipsc_cvpc arteria isoform_use h.all
# 36729 heart     arteria isoform_use h.all
# 36730 ipsc_cvpc heart   isoform_use h.all
# 36731 ipsc_cvpc arteria isoform_use h.all
# 36732 heart     arteria isoform_use h.all
# 36733 ipsc_cvpc heart   isoform_use h.all
# 36734 ipsc_cvpc arteria isoform_use h.all
# 36735 heart     arteria isoform_use h.all
# 36736 ipsc_cvpc heart   isoform_use h.all
# 36737 ipsc_cvpc arteria isoform_use h.all
# 36738 heart     arteria isoform_use h.all
# 36739 ipsc_cvpc heart   isoform_use h.all
# 36740 ipsc_cvpc arteria isoform_use h.all
# 36741 heart     arteria isoform_use h.all
# 36742 ipsc_cvpc heart   isoform_use h.all
# 36743 ipsc_cvpc arteria isoform_use h.all
# 36744 heart     arteria isoform_use h.all
# 36745 ipsc_cvpc heart   isoform_use h.all
# 36746 ipsc_cvpc arteria isoform_use h.all
# 36747 heart     arteria isoform_use h.all
#       gene_set
# 1     BIOCARTA_RELA_PATHWAY
# 2     BIOCARTA_RELA_PATHWAY
# 3     BIOCARTA_RELA_PATHWAY
# 4     BIOCARTA_NO1_PATHWAY
# 5     BIOCARTA_NO1_PATHWAY
# 6     BIOCARTA_NO1_PATHWAY
# 7     BIOCARTA_CSK_PATHWAY
# 8     BIOCARTA_CSK_PATHWAY
# 9     BIOCARTA_CSK_PATHWAY
# 10    BIOCARTA_SRCRPTP_PATHWAY
# 11    BIOCARTA_SRCRPTP_PATHWAY
# 12    BIOCARTA_SRCRPTP_PATHWAY
# 13    BIOCARTA_AMI_PATHWAY
# 14    BIOCARTA_AMI_PATHWAY
# 15    BIOCARTA_AMI_PATHWAY
# 16    BIOCARTA_GRANULOCYTES_PATHWAY
# 17    BIOCARTA_GRANULOCYTES_PATHWAY
# 18    BIOCARTA_GRANULOCYTES_PATHWAY
# 19    BIOCARTA_LYM_PATHWAY
# 20    BIOCARTA_LYM_PATHWAY
# 21    BIOCARTA_LYM_PATHWAY
# 22    BIOCARTA_ARAP_PATHWAY
# 23    BIOCARTA_ARAP_PATHWAY
# 24    BIOCARTA_ARAP_PATHWAY
# 25    BIOCARTA_AGR_PATHWAY
# 26    BIOCARTA_AGR_PATHWAY
# 27    BIOCARTA_AGR_PATHWAY
# 28    BIOCARTA_AKAP95_PATHWAY
# 29    BIOCARTA_AKAP95_PATHWAY
# 30    BIOCARTA_AKAP95_PATHWAY
# ⋮     ⋮
# 36718 HALLMARK_HEME_METABOLISM
# 36719 HALLMARK_HEME_METABOLISM
# 36720 HALLMARK_HEME_METABOLISM
# 36721 HALLMARK_COAGULATION
# 36722 HALLMARK_COAGULATION
# 36723 HALLMARK_COAGULATION
# 36724 HALLMARK_IL2_STAT5_SIGNALING
# 36725 HALLMARK_IL2_STAT5_SIGNALING
# 36726 HALLMARK_IL2_STAT5_SIGNALING
# 36727 HALLMARK_BILE_ACID_METABOLISM
# 36728 HALLMARK_BILE_ACID_METABOLISM
# 36729 HALLMARK_BILE_ACID_METABOLISM
# 36730 HALLMARK_PEROXISOME
# 36731 HALLMARK_PEROXISOME
# 36732 HALLMARK_PEROXISOME
# 36733 HALLMARK_ALLOGRAFT_REJECTION
# 36734 HALLMARK_ALLOGRAFT_REJECTION
# 36735 HALLMARK_ALLOGRAFT_REJECTION
# 36736 HALLMARK_SPERMATOGENESIS
# 36737 HALLMARK_SPERMATOGENESIS
# 36738 HALLMARK_SPERMATOGENESIS
# 36739 HALLMARK_KRAS_SIGNALING_UP
# 36740 HALLMARK_KRAS_SIGNALING_UP
# 36741 HALLMARK_KRAS_SIGNALING_UP
# 36742 HALLMARK_KRAS_SIGNALING_DN
# 36743 HALLMARK_KRAS_SIGNALING_DN
# 36744 HALLMARK_KRAS_SIGNALING_DN
# 36745 HALLMARK_PANCREAS_BETA_CELLS
# 36746 HALLMARK_PANCREAS_BETA_CELLS
# 36747 HALLMARK_PANCREAS_BETA_CELLS
#       url
# 1     http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_RELA_PATHWAY
# 2     http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_RELA_PATHWAY
# 3     http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_RELA_PATHWAY
# 4     http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_NO1_PATHWAY
# 5     http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_NO1_PATHWAY
# 6     http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_NO1_PATHWAY
# 7     http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_CSK_PATHWAY
# 8     http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_CSK_PATHWAY
# 9     http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_CSK_PATHWAY
# 10    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_SRCRPTP_PATHWAY
# 11    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_SRCRPTP_PATHWAY
# 12    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_SRCRPTP_PATHWAY
# 13    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_AMI_PATHWAY
# 14    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_AMI_PATHWAY
# 15    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_AMI_PATHWAY
# 16    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_GRANULOCYTES_PATHWAY
# 17    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_GRANULOCYTES_PATHWAY
# 18    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_GRANULOCYTES_PATHWAY
# 19    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_LYM_PATHWAY
# 20    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_LYM_PATHWAY
# 21    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_LYM_PATHWAY
# 22    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_ARAP_PATHWAY
# 23    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_ARAP_PATHWAY
# 24    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_ARAP_PATHWAY
# 25    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_AGR_PATHWAY
# 26    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_AGR_PATHWAY
# 27    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_AGR_PATHWAY
# 28    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_AKAP95_PATHWAY
# 29    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_AKAP95_PATHWAY
# 30    http://www.gsea-msigdb.org/gsea/msigdb/cards/BIOCARTA_AKAP95_PATHWAY
# ⋮     ⋮
# 36718 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_HEME_METABOLISM
# 36719 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_HEME_METABOLISM
# 36720 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_HEME_METABOLISM
# 36721 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_COAGULATION
# 36722 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_COAGULATION
# 36723 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_COAGULATION
# 36724 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_IL2_STAT5_SIGNALING
# 36725 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_IL2_STAT5_SIGNALING
# 36726 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_IL2_STAT5_SIGNALING
# 36727 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_BILE_ACID_METABOLISM
# 36728 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_BILE_ACID_METABOLISM
# 36729 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_BILE_ACID_METABOLISM
# 36730 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_PEROXISOME
# 36731 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_PEROXISOME
# 36732 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_PEROXISOME
# 36733 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_ALLOGRAFT_REJECTION
# 36734 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_ALLOGRAFT_REJECTION
# 36735 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_ALLOGRAFT_REJECTION
# 36736 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_SPERMATOGENESIS
# 36737 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_SPERMATOGENESIS
# 36738 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_SPERMATOGENESIS
# 36739 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_KRAS_SIGNALING_UP
# 36740 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_KRAS_SIGNALING_UP
# 36741 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_KRAS_SIGNALING_UP
# 36742 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_KRAS_SIGNALING_DN
# 36743 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_KRAS_SIGNALING_DN
# 36744 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_KRAS_SIGNALING_DN
# 36745 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_PANCREAS_BETA_CELLS
# 36746 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_PANCREAS_BETA_CELLS
# 36747 http://www.gsea-msigdb.org/gsea/msigdb/cards/HALLMARK_PANCREAS_BETA_CELLS
#       ngenes dif_yes dif_no ns_yes ns_no estimate  ci1         ci2
# 1     13     0       357    13     10303  0.000000 0.00000000    9.508920
# 2     13     0       587    13     10073  0.000000 0.00000000    5.646502
# 3     13     0       105    13     10555  0.000000 0.00000000   33.461653
# 4     12     1       356    11     10305  2.631128 0.06096736   18.190303
# 5     12     1       586    11     10075  1.562884 0.03625091   10.788693
# 6     12     0       105    12     10556  0.000000 0.00000000   36.674787
# 7      7     0       357     7     10309  0.000000 0.00000000   20.104871
# 8      7     0       587     7     10079  0.000000 0.00000000   11.939444
# 9      7     0       105     7     10561  0.000000 0.00000000   70.617145
# 10     6     0       357     6     10310  0.000000 0.00000000   24.611645
# 11     6     1       586     5     10081  3.439899 0.07262149   30.812929
# 12     6     0       105     6     10562  0.000000 0.00000000   86.433381
# 13     8     0       357     8     10308  0.000000 0.00000000   16.980120
# 14     8     0       587     8     10078  0.000000 0.00000000   10.083615
# 15     8     0       105     8     10560  0.000000 0.00000000   59.719818
# 16     9     0       357     9     10307  0.000000 0.00000000   14.684484
# 17     9     1       586     8     10078  2.149624 0.04836593   16.075765
# 18     9     0       105     9     10559  0.000000 0.00000000   51.621533
# 19     7     0       357     7     10309  0.000000 0.00000000   20.104871
# 20     7     1       586     6     10080  2.866431 0.06222208   23.685211
# 21     7     1       104     6     10562 16.904867 0.36451532  141.163381
# 22     7     1       356     6     10310  4.825831 0.10464482   39.958052
# 23     7     0       587     7     10079  0.000000 0.00000000   11.939444
# 24     7     0       105     7     10561  0.000000 0.00000000   70.617145
# 25    21     0       357    21     10295  0.000000 0.00000000    5.564840
# 26    21     3       584    18     10068  2.872822 0.54051728    9.883535
# 27    21     1       104    20     10548  5.069968 0.12119920   32.266533
# 28     6     0       357     6     10310  0.000000 0.00000000   24.611645
# 29     6     0       587     6     10080  0.000000 0.00000000   14.618087
# 30     6     0       105     6     10562  0.000000 0.00000000   86.433381
# ⋮     ⋮      ⋮       ⋮      ⋮      ⋮     ⋮         ⋮           ⋮
# 36718 130    7       350    123    10193 1.6572891 0.647809398  3.5551768
# 36719 130    6       581    124     9962 0.8296679 0.297466475  1.8690220
# 36720 130    2       103    128    10440 1.5836308 0.187224334  5.9854678
# 36721  64    3       354     61    10255 1.4246237 0.284513052  4.3986267
# 36722  64    5       582     59    10027 1.4599652 0.455477294  3.6231703
# 36723  64    0       105     64    10504 0.0000000 0.000000000  6.0375392
# 36724 134    1       356    133    10183 0.2150836 0.005393233  1.2270855
# 36725 134    2       585    132     9954 0.2578277 0.030830623  0.9543596
# 36726 134    1       104    133    10435 0.7544272 0.018780933  4.3700022
# 36727  58    4       353     54    10262 2.1530924 0.563188579  5.8882531
# 36728  58    5       582     53    10033 1.6261995 0.505341014  4.0609096
# 36729  58    0       105     58    10510 0.0000000 0.000000000  6.6860276
# 36730  67    4       353     63    10253 1.8440979 0.484674614  5.0019247
# 36731  67    7       580     60    10026 2.0165467 0.774084450  4.4425165
# 36732  67    1       104     66    10502 1.5299029 0.037806632  9.0123375
# 36733  99    3       354     96    10220 0.9021971 0.181952196  2.7386040
# 36734  99    6       581     93     9993 1.1096367 0.395365625  2.5231448
# 36735  99    1       104     98    10470 1.0272827 0.025506788  5.9861401
# 36736  50    0       357     50    10266 0.0000000 0.000000000  2.2132198
# 36737  50    1       586     49    10037 0.3495729 0.008663466  2.0489296
# 36738  50    3       102     47    10521 6.5805954 1.289376148 20.9788543
# 36739 120    0       357    120    10196 0.0000000 0.000000000  0.8963292
# 36740 120    5       582    115     9971 0.7448916 0.236446061  1.7995859
# 36741 120    0       105    120    10448 0.0000000 0.000000000  3.1612960
# 36742  64    2       355     62    10254 0.9317641 0.109956680  3.5357604
# 36743  64    0       587     64    10022 0.0000000 0.000000000  1.0163323
# 36744  64    2       103     62    10506 3.2896129 0.384652468 12.6968181
# 36745  10    0       357     10    10306 0.0000000 0.000000000 12.9302912
# 36746  10    0       587     10    10076 0.0000000 0.000000000  7.6791637
# 36747  10    0       105     10    10558 0.0000000 0.000000000 45.4905396
#       pval       fdr
# 1     1.00000000 1
# 2     1.00000000 1
# 3     1.00000000 1
# 4     0.33533183 1
# 5     0.49297072 1
# 6     1.00000000 1
# 7     1.00000000 1
# 8     1.00000000 1
# 9     1.00000000 1
# 10    1.00000000 1
# 11    0.28787015 1
# 12    1.00000000 1
# 13    1.00000000 1
# 14    1.00000000 1
# 15    1.00000000 1
# 16    1.00000000 1
# 17    0.39909366 1
# 18    1.00000000 1
# 19    1.00000000 1
# 20    0.32705832 1
# 21    0.06688414 1
# 22    0.21196740 1
# 23    1.00000000 1
# 24    1.00000000 1
# 25    1.00000000 1
# 26    0.10554889 1
# 27    0.18764251 1
# 28    1.00000000 1
# 29    1.00000000 1
# 30    1.00000000 1
# ⋮     ⋮          ⋮
# 36718 0.21020193 1
# 36719 0.84615968 1
# 36720 0.36677150 1
# 36721 0.47466798 1
# 36722 0.40106422 1
# 36723 1.00000000 1
# 36724 0.13830143 1
# 36725 0.03478397 1
# 36726 1.00000000 1
# 36727 0.12850569 1
# 36728 0.25024007 1
# 36729 1.00000000 1
# 36730 0.28727134 1
# 36731 0.09644696 1
# 36732 0.48545408 1
# 36733 1.00000000 1
# 36734 0.82272651 1
# 36735 0.62593266 1
# 36736 0.41555383 1
# 36737 0.52551553 1
# 36738 0.01297575 1
# 36739 0.03561384 1
# 36740 0.68675187 1
# 36741 0.63428501 1
# 36742 1.00000000 1
# 36743 0.04984457 1
# 36744 0.13074389 1
# 36745 1.00000000 1
# 36746 1.00000000 1
# 36747 1.00000000 1
