# %% [markdown]
# # Test if eQTLs for RNA binding proteins are associated with the expression of isoforms that have the RBP binding
# - RBP binding: from eCLIP: `/frazer01/home/tarthur/projects/CARDIPS/rbp_analysis/sorted_bed/`

# %%
setwd("/frazer01/projects/CARDIPS/analysis/cardiac_eqtls")

source("script/packages.R"  )
source("script/input_data.R")
source("script/functions.R" )
source("script/colors.R"    )

# %%
geneinfo_gene_all   = fread("input/phenotypes/gene_info.txt"          , sep = "\t", header = TRUE , data.table = FALSE)
geneinfo_gene       = fread("pipeline/1.2.expression/gene_info.txt"   , sep = "\t", header = TRUE , data.table = FALSE)
geneinfo_isoform    = fread("pipeline/1.2.expression/isoform_info.txt", sep = "\t", header = TRUE , data.table = FALSE)
diffexp             = fread("pipeline/4.1.differential_expression/diffexp.txt", sep = "\t", header = TRUE , data.table = FALSE)
eqtl_genes          = fread("pipeline/3.2.eqtls/eqtls/cardiac_eqtls.gene.egenes.txt"         , sep = "\t", header = TRUE , data.table = FALSE)

# %%
rbp_folder         = "/frazer01/home/tarthur/projects/CARDIPS/rbp_analysis/sorted_peaks"
rbpbs_list         = list.files(rbp_folder, pattern = "bed$", full.names = TRUE)
rbp_meta           = fread("/reference/public/ENCODE/rbp_eclip_2020_09_09/metadata.tsv", sep = "\t", header = TRUE, data.table = FALSE)
rbp_meta           = rbp_meta[,c("File accession", "File format type", "File assembly", "Assay", "Biosample term name", "Experiment target")]
colnames(rbp_meta) = c("id", "filetype", "assembly", "assay", "cell_line", "gene_name")
rbp_meta$infile    = paste(rbp_folder, paste(rbp_meta$id, "bed", sep = "."), sep = "/")
rbp_meta$gene_name = gsub("-human", "", rbp_meta$gene_name)
rbp_meta           = rbp_meta[rbp_meta$infile %in% rbpbs_list & rbp_meta$assembly == "hg19",]
rbp_meta           = merge(rbp_meta, geneinfo_gene_all[geneinfo_gene_all$gene_id != "ENSG00000280987.4_7",c("gene_name", "gene_id")])
rbp_meta           = merge(rbp_meta, diffexp[diffexp$type == "gene_tpm" & diffexp$tissue1 == "ipsc_cvpc" & diffexp$tissue2 == "heart", c("gene_id", "beta", "pval", "qval", "diffexp")], all.x = TRUE)

# %% [markdown]
# # Intersect RBPs with isoform positions

# %%
rbp_data = as.data.frame(rbindlist(lapply(rbp_meta$infile, function(x)
{
    indata = fread(x, sep = "\t", header = FALSE, data.table = FALSE)
    indata = indata[,1:4]
    
    return(indata)
})), stringsAsFactors = FALSE)

colnames(rbp_data) = c("chrom", "from", "to", "id")
rbp_data           = rbp_data[order(rbp_data$chrom, rbp_data$from, rbp_data$to),]
rbp_bed            = paste(getwd(), "pipeline/7.1.trans/rbp/input", "rbp.bed", sep = "/")

fwrite(rbp_data, rbp_bed, sep = "\t", col.names = FALSE, row.names = FALSE)

# %%
intersected_file = paste(getwd(), "pipeline/7.1.trans/rbp/input", "intersected.bed", sep = "/")
command          = paste("bedtools", "intersect", "-loj", "-a", rbp_bed, "-b", "/reference/private/Gencode.v34lift37/isoform.bed", ">", intersected_file)

#system(command)

# %%
intersected           = fread(intersected_file, sep = "\t", header = FALSE, data.table = FALSE)
intersected           = intersected[,c(8,4)]
colnames(intersected) = c("transcript_id", "x")
intersected$rbp_name  = unlist(lapply(intersected$x, function(x){unlist(strsplit(x, "_"))[[1]]}))
#intersected           = unique(intersected)

# %%
isoform2rbp = aggregate(x ~ rbp_name + transcript_id, data = intersected[intersected$transcript_id != ".",], FUN = length)

# %%
fwrite(isoform2rbp, "pipeline/7.1.trans/rbp/input/isoform2rbp.txt", sep = "\t", col.names = TRUE, row.names = FALSE)

# %% [markdown]
# # Get eQTL information for each RBP

# %%
eqtl_rbp = eqtl_genes[eqtl_genes$gene_id %in% rbp_meta$gene_id, ]
fwrite(eqtl_rbp, "pipeline/7.1.trans/rbp/input/eqtl_rbp.txt", sep = "\t", col.names = TRUE, row.names = FALSE)

# %%
invisible(lapply(sort(unique(eqtl_rbp$gene_id)), function(rbp)
{
    indata = isoform2rbp[ isoform2rbp$rbp_name == geneinfo_gene[geneinfo_gene$gene_id == rbp, "gene_name"],]
    indata = indata[indata$transcript_id %in% geneinfo_isoform$transcript_id,]
    
    fwrite(indata[,c("transcript_id", "x")], paste("pipeline/7.1.trans/rbp/input/rbp2transcript", paste(rbp, "txt", sep = "."), sep = "/"), sep = "\t", col.names = TRUE, row.names = FALSE)
}))

# %% [markdown]
# # Run trans-analysis

# %%
run_trans_eqtls_qsub = function()
{
    
    sh_file = paste(getwd(), "pipeline/7.1.trans/script", paste("run.7.1", "rbp", "sh", sep = "."), sep = "/")
    
    writeLines(text = c("#!/usr/bin/sh",
                        "source /frazer01/home/matteo/.bashrc",
                        paste("Rscript", paste(paste(getwd(), "script", "7.2.run_trans_eqtls_rbp.R", sep = "/"),"--taskid", "$SGE_TASK_ID"))
                       ), 
               con  = sh_file, 
               sep  = "\n\n")
    
    qsub_command = paste("qsub",
                         "-l", "short",
                         "-t", paste(1, "-", nrow(eqtl_rbp), ":1", sep = ""),
                         "-tc", 500, 
                         "-o" , paste(getwd(), paste("logs/eqtls", "7.2.run_trans_eqtls_rbp", "out", sep = "."), sep = "/"),
                         "-e" , paste(getwd(), paste("logs/eqtls", "7.2.run_trans_eqtls_rbp", "err", sep = "."), sep = "/"),
                         sh_file
                        )
    
    message(qsub_command)
    system(qsub_command)
}

run_trans_eqtls_qsub() # run all genes
# Out:
# qsub -l short -t 1-240:1 -tc 500 -o /frazer01/projects/CARDIPS/analysis/cardiac_eqtls/logs/eqtls.7.2.run_trans_eqtls_rbp.out -e /frazer01/projects/CARDIPS/analysis/cardiac_eqtls/logs/eqtls.7.2.run_trans_eqtls_rbp.err /frazer01/projects/CARDIPS/analysis/cardiac_eqtls/pipeline/7.1.trans/script/run.7.1.rbp.sh
#
# Warning message in system(qsub_command):
# “system call failed: Cannot allocate memory”
# Warning message in system(qsub_command):
# “error in running command”

# %% [markdown]
# # Private: test trans analysis

# %%
taskid = 2

# %%
exp_all          = add_rownames(fread("pipeline/1.2.expression//use_isoform.normalized.txt", sep = "\t", header = TRUE , data.table = FALSE))

# %%
gt_folder           = paste(getwd(), "pipeline", "1.3.genotype"  , "tpm_gene"   , sep = "/")
geneinfo_gene       = fread("pipeline/1.2.expression/gene_info.txt"                          , sep = "\t", header = TRUE , data.table = FALSE)
geneinfo_isoform    = fread("pipeline/1.2.expression/isoform_info.txt"                       , sep = "\t", header = TRUE , data.table = FALSE)
eqtl_rbp            = fread("pipeline/7.1.trans/rbp/input/eqtl_rbp.txt"                      , sep = "\t", header = TRUE , data.table = FALSE)
eqtl                = eqtl_rbp[taskid, c("gene_id", "gene_name", "type", "chrom", "pos", "ref", "alt", "id", "beta", "se", "pval", "fdr", "qval", "egene")]
rbp                 = eqtl$gene_id
totest              = fread(paste("pipeline/7.1.trans/rbp/input/rbp2transcript", paste(rbp, "txt", sep = "."), sep = "/"), sep = "\t", header = TRUE , data.table = FALSE)
vars0               = readLines(paste("pipeline/3.2.eqtls", "vars", paste("cardiac_eqtls", "isoform", "txt", sep = "."), sep = "/"))
exp_rbp             = add_rownames(fread(paste(paste(getwd(), "pipeline", "1.2.expression", "tpm_gene", sep = "/"), paste(rbp, "txt", sep = "."), sep = "/"), sep = "\t", header = TRUE , data.table = FALSE))
covariates          = add_rownames(fread("pipeline/3.1.covariates/covariates.txt", sep = "\t", header = TRUE , data.table = FALSE))
metadata            =              fread("pipeline/3.1.covariates/metadata.txt"  , sep = "\t", header = TRUE , data.table = FALSE)
gtdata              = add_rownames(fread(paste(gt_folder , paste("gt_data", rbp, "txt", sep = "."), sep = "/"), sep = "\t", header = TRUE , data.table = FALSE))
covariates          =              merge(metadata, covariates, by.x = "run", by.y = "row.names")
covariates          = merge(covariates, data.frame(wgs_id = colnames(gtdata), gt = as.numeric(gtdata[eqtl$id,])))

# %%
isoform = totest[1, "transcript_id"]

# %%
calculate_trans = function(x, name, tolm, vars0)
{
    tolm$totest    = tolm[,x]
    out0           = as.data.frame(summary(lm(norm_isoform ~ ., data = tolm[,c("norm_isoform", "totest", "norm", vars0)]))$coefficients)
    out0           = out0["totest", c("Estimate", "Std. Error", "Pr(>|t|)")]
    colnames(out0) = paste(c("beta", "se", "pval"), name, sep = "_")
    
    return(out0)
}

out = as.data.frame(rbindlist(lapply(rownames(exp_all), function(isoform)
{
    expdata                  = data.frame(run = colnames(exp_all), norm_isoform = as.numeric(exp_all[isoform,]))
    tolm                     = merge(covariates, expdata, by   = "run")
    tolm                     = merge(tolm      , exp_rbp, by.x = "run", by.y = "row.names")
    out_gt                   = calculate_trans("gt"  , "gt" , tolm, vars0)
    out_ex                   = calculate_trans("norm", "exp", tolm, vars0)
    out0                     = cbind(eqtl[,c("gene_id", "gene_name", "type")], out_gt, out_ex)
    out0$transcript_id_trans = isoform  
    
    return(out0)
})), stringsAsFactors = FALSE)

fwrite(out, paste("pipeline/7.1.trans/rbp/trans_eqtls_by_rbp", paste(rbp, "txt", sep = "."), sep = "/"), sep = "\t", col.names = TRUE, row.names = FALSE)

# %%
out
# Out:
#    gene_id             gene_name type beta_gt      se_gt      pval_gt
# 1  ENSG00000004478.8_4 FKBP4     0     0.009097402 0.09815838 0.92617872
# 2  ENSG00000004478.8_4 FKBP4     0    -0.145590625 0.10858625 0.18034530
# 3  ENSG00000004478.8_4 FKBP4     0     0.156038611 0.11132992 0.16139969
# 4  ENSG00000004478.8_4 FKBP4     0     0.051821544 0.09563707 0.58805805
# 5  ENSG00000004478.8_4 FKBP4     0    -0.182392447 0.09181826 0.04730068
# 6  ENSG00000004478.8_4 FKBP4     0    -0.175797270 0.09914612 0.07656430
# 7  ENSG00000004478.8_4 FKBP4     0    -0.033159763 0.10191495 0.74498254
# 8  ENSG00000004478.8_4 FKBP4     0     0.124295003 0.09954080 0.21212087
# 9  ENSG00000004478.8_4 FKBP4     0     0.110927507 0.08838833 0.20981943
# 10 ENSG00000004478.8_4 FKBP4     0     0.035656397 0.11061518 0.74726878
#    beta_exp    se_exp     pval_exp  transcript_id_trans
# 1  -0.04602705 0.07474442 0.5381945 ENST00000373020.9_3
# 2   0.10842578 0.08277097 0.1905628 ENST00000614008.4_2
# 3  -0.06932271 0.08487057 0.4142661 ENST00000496771.5_2
# 4   0.05734375 0.07283661 0.4313273 ENST00000371588.9_2
# 5  -0.08345882 0.07007668 0.2339962 ENST00000371582.8_3
# 6   0.03404474 0.07563421 0.6527348 ENST00000367771.11_4
# 7   0.08132829 0.07760932 0.2949703 ENST00000367770.5_3
# 8  -0.08752642 0.07586547 0.2489414 ENST00000367772.8_3
# 9   0.02577185 0.06736618 0.7021379 ENST00000374005.8_3
# 10  0.06417893 0.08423454 0.4463241 ENST00000399173.5_2

# %%
metadata
# Out:
#     run                                  assay_id
# 1   013eb23c-4ff0-493b-b106-9c8c9c2176d6 013eb23c-4ff0-493b-b106-9c8c9c2176d6
# 2   028df3e3-a041-4f91-9da7-517a7a33e271 028df3e3-a041-4f91-9da7-517a7a33e271
# 3   030ec865-77e5-4e82-9b18-77a51e787655 030ec865-77e5-4e82-9b18-77a51e787655
# 4   03df2c1b-bcc6-4fa3-9f47-d6f9e43be283 03df2c1b-bcc6-4fa3-9f47-d6f9e43be283
# 5   067afe59-e81d-4176-800d-f1b111c1ec82 067afe59-e81d-4176-800d-f1b111c1ec82
# 6   0716c9fa-8153-477d-8e24-6abee17c9456 0716c9fa-8153-477d-8e24-6abee17c9456
# 7   0726b84c-c9ed-45a8-b50b-e1e8f484be8e 0726b84c-c9ed-45a8-b50b-e1e8f484be8e
# 8   08f6fa0b-14ea-4ac6-85ec-67045c15d5ac 08f6fa0b-14ea-4ac6-85ec-67045c15d5ac
# 9   0b111711-0130-44aa-b513-a308d13d1652 0b111711-0130-44aa-b513-a308d13d1652
# 10  0c025698-b29b-4f3f-adab-c41cffc53911 0c025698-b29b-4f3f-adab-c41cffc53911
# 11  0d9f7f72-66ea-411a-906b-868c1c5bffbe 0d9f7f72-66ea-411a-906b-868c1c5bffbe
# 12  0e4a2a0e-ef6b-41ce-bc63-d71f6c9fe2c1 0e4a2a0e-ef6b-41ce-bc63-d71f6c9fe2c1
# 13  0e55634f-9393-4a55-90df-3ba2d13edbb0 0e55634f-9393-4a55-90df-3ba2d13edbb0
# 14  0f8dc931-9339-4545-a3c6-3d2710174da7 0f8dc931-9339-4545-a3c6-3d2710174da7
# 15  10945496-f15f-46c1-b7c7-a94379658d42 10945496-f15f-46c1-b7c7-a94379658d42
# 16  13756c7c-77dc-46d3-9c14-7debadb42dc0 13756c7c-77dc-46d3-9c14-7debadb42dc0
# 17  13b129fd-2c4a-4d12-a21c-3534efa9babc 13b129fd-2c4a-4d12-a21c-3534efa9babc
# 18  1418f45b-e731-4180-9c3b-990391b1ff49 1418f45b-e731-4180-9c3b-990391b1ff49
# 19  17891495-09c9-470f-a50d-244c4ae63ccd 17891495-09c9-470f-a50d-244c4ae63ccd
# 20  1957bd34-8e9d-4190-b4e2-b3e548ec6b86 1957bd34-8e9d-4190-b4e2-b3e548ec6b86
# 21  1bb91c1e-4b24-4d08-9701-bf9f1dcf51c6 1bb91c1e-4b24-4d08-9701-bf9f1dcf51c6
# 22  1e030be8-3362-4f86-b15b-2aaaff1ef35b 1e030be8-3362-4f86-b15b-2aaaff1ef35b
# 23  1eb2f150-f6a6-48ea-937f-38495099ec35 1eb2f150-f6a6-48ea-937f-38495099ec35
# 24  1f05f617-aedf-4970-9ab2-10b32737ffd7 1f05f617-aedf-4970-9ab2-10b32737ffd7
# 25  1f59047b-9ba1-45d2-93f5-4f669be31732 1f59047b-9ba1-45d2-93f5-4f669be31732
# 26  21f31a89-cbae-4252-8b47-a983fd2eaae5 21f31a89-cbae-4252-8b47-a983fd2eaae5
# 27  252626cb-fdee-49bc-b39b-f7e2d330f56a 252626cb-fdee-49bc-b39b-f7e2d330f56a
# 28  26e04bc3-24e8-4565-b087-cae1acf0bbf7 26e04bc3-24e8-4565-b087-cae1acf0bbf7
# 29  28e21163-cd01-4302-a75b-440b772d54fb 28e21163-cd01-4302-a75b-440b772d54fb
# 30  28fbc85b-148d-4935-bbfe-0572e1399eee 28fbc85b-148d-4935-bbfe-0572e1399eee
# ⋮   ⋮                                    ⋮
# 937 SRR811891                            GTEX-WHSE-0926-SM-3NMBS
# 938 SRR812222                            GTEX-WK11-0626-SM-3NMAV
# 939 SRR812649                            GTEX-WYBS-1226-SM-3NM9N
# 940 SRR812673                            GTEX-P44H-1026-SM-3NM96
# 941 SRR813632                            GTEX-PLZ5-0426-SM-3P612
# 942 SRR813728                            GTEX-X261-0926-SM-3NMCY
# 943 SRR813915                            GTEX-WHWD-0326-SM-3LK6L
# 944 SRR814587                            GTEX-WY7C-1126-SM-3NB3A
# 945 SRR814611                            GTEX-WQUQ-1426-SM-3MJFD
# 946 SRR815092                            GTEX-P4PQ-0426-SM-3NMCI
# 947 SRR815184                            GTEX-X4XX-1126-SM-3NMBY
# 948 SRR815517                            GTEX-WWYW-1326-SM-3NB2S
# 949 SRR815661                            GTEX-WH7G-0426-SM-3NMBJ
# 950 SRR815735                            GTEX-WZTO-1326-SM-3NM8X
# 951 SRR815893                            GTEX-X3Y1-0226-SM-3P5Z5
# 952 SRR816064                            GTEX-WHWD-0426-SM-3LK83
# 953 SRR816358                            GTEX-WYJK-1026-SM-3NM8W
# 954 SRR816565                            GTEX-PLZ6-0326-SM-3P61J
# 955 SRR817563                            GTEX-WHPG-1026-SM-3NMBA
# 956 SRR817744                            GTEX-OHPM-0426-SM-3TW8V
# 957 SRR817825                            GTEX-WI4N-0626-SM-3TW8Z
# 958 SRR818530                            GTEX-WI4N-0726-SM-3TW93
# 959 SRR818999                            GTEX-P4QS-0426-SM-3NMCQ
# 960 SRR819293                            GTEX-P4PP-0426-SM-3NM9H
# 961 SRR819583                            GTEX-O5YW-3026-SM-3MJHI
# 962 SRR820316                            GTEX-O5YT-0326-SM-32PKA
# 963 SRR820492                            GTEX-NPJ8-1326-SM-3LK6B
# 964 SRR821183                            GTEX-WWYW-1126-SM-3NB2Q
# 965 SRR821388                            GTEX-NPJ7-1326-SM-3MJHO
# 966 SRR821846                            GTEX-P4PP-3026-SM-3P61O
#     wgs_id                               subject_id
# 1   583d5465-f933-46d1-9fa4-307b76b97311 bd04a8cc-5d63-45bc-a2cc-91b0c7cb6e01
# 2   c08cc10c-44c1-4fa4-897a-636f5dfb058f bd4643a6-9742-4a25-8029-a967cc2a84c7
# 3   b0efcf59-dea7-4f62-bf01-41bf08422001 e0793a72-9694-4711-a2c6-d2ff9071d05f
# 4   99dc8247-0416-44c2-854d-a2e31066a75b 508fb6c5-c9d5-4881-9638-cd4bd04d822f
# 5   78d8c099-465b-412d-bf88-e7ae54366e34 03346cae-a4f3-4481-92ff-d76db0c82468
# 6   c643713c-38f0-4514-b820-a566801a386a bfee9a02-5ec3-4e11-a8e2-ebd47623caa0
# 7   c5b18bcb-bbb9-43ee-989a-717c14371257 f0173728-58cb-4d7d-b28d-02355b49b9ed
# 8   01fe3fd3-5392-45e6-93b7-448151107e1d 83a1b295-b907-4233-b0a8-df753b2cee16
# 9   90657981-484d-444a-9b2b-9b479f84c8c6 42e4583a-b1bc-4cc3-85d7-68662433b345
# 10  8ae6e66c-b3a2-436a-8a28-94356cd373fd d4073658-c7fe-4f53-9e80-b95121a65475
# 11  2cd75846-7673-4868-b5fc-590879d0d3de 21f44f41-69ee-427c-933b-a0afdc16a0bf
# 12  ccd5d306-6ed1-4515-acd1-1be1d9f2a49a 5b8ca416-c75e-4341-b160-3b9be09f6ef5
# 13  88569604-9241-4c77-87ce-c47e9a85f4a3 92516175-d525-442e-bd5a-816a1962d37d
# 14  c7a966f7-e22e-4807-afff-2bae9ca5fc72 9d988cb0-01b1-4d5d-bf4b-3fd3baf149a4
# 15  428c15bd-f79e-427c-b57b-591518885437 56f0f073-725f-4cec-b8cb-db6ad0dc2ac0
# 16  9127d78b-54a1-4be2-a6b9-40097c8cbc5a 62d833a3-87c8-40a2-8261-d172f4c0e7fe
# 17  251a999a-05dd-4ad8-a530-c188ecc5b795 5482a5d3-6f16-483b-9c14-ca2f838d6af9
# 18  f4b0146d-7508-457f-a754-bb4042583c4b 10f10a94-511f-4538-9c0c-cbe5fdb14b6c
# 19  499531da-aae2-47f4-9a07-fac1baf6324c fc1dff0a-6a95-42fe-9dc4-362e27330bf9
# 20  c17006e1-8649-4e9e-ba4f-7bd4ee752244 60bd2a54-fecd-4c6e-8442-b13f66d869a6
# 21  ae757c28-7757-4a5e-9016-9d89dbf56499 17911abe-0893-4919-b45e-5df3d3fe63c8
# 22  3ba3d4d5-9589-4f74-aa4c-28a96f8c222b 72739241-3ddb-41ab-8438-150e20619de1
# 23  2cd75846-7673-4868-b5fc-590879d0d3de 21f44f41-69ee-427c-933b-a0afdc16a0bf
# 24  024f3a84-e1ec-4049-95e7-ecc8f39697f0 f80deca1-0641-4a52-86b5-7b01c227ba8a
# 25  3ff1ec68-6cb9-4f9f-b2c8-5f318be79163 416e2905-329b-44ed-bb02-8a3b1ed6847e
# 26  f8d173dd-c608-48a1-bf14-3a72f76c05ed cfd3b543-2da8-4262-ae36-7ee27c0b5c6b
# 27  f3284741-0362-4f47-8ee8-191acf41d7ac 201da1fb-3779-4344-af69-6e3bf1c58261
# 28  5e99cc57-3fb2-42b4-8a11-048f71387a38 b9e30469-13ad-4792-878a-889cd6480f91
# 29  c0fde6a4-7316-4519-b48d-08e76684562f f772212a-cd98-40f9-bdcd-e75740c1f6be
# 30  2fd8fb69-d84c-4dc7-ac78-3cc511acd829 9e7013ce-054f-46ae-bc49-4abe5d53d88a
# ⋮   ⋮                                    ⋮
# 937 GTEX-WHSE                            GTEX-WHSE
# 938 GTEX-WK11                            GTEX-WK11
# 939 GTEX-WYBS                            GTEX-WYBS
# 940 GTEX-P44H                            GTEX-P44H
# 941 GTEX-PLZ5                            GTEX-PLZ5
# 942 GTEX-X261                            GTEX-X261
# 943 GTEX-WHWD                            GTEX-WHWD
# 944 GTEX-WY7C                            GTEX-WY7C
# 945 GTEX-WQUQ                            GTEX-WQUQ
# 946 GTEX-P4PQ                            GTEX-P4PQ
# 947 GTEX-X4XX                            GTEX-X4XX
# 948 GTEX-WWYW                            GTEX-WWYW
# 949 GTEX-WH7G                            GTEX-WH7G
# 950 GTEX-WZTO                            GTEX-WZTO
# 951 GTEX-X3Y1                            GTEX-X3Y1
# 952 GTEX-WHWD                            GTEX-WHWD
# 953 GTEX-WYJK                            GTEX-WYJK
# 954 GTEX-PLZ6                            GTEX-PLZ6
# 955 GTEX-WHPG                            GTEX-WHPG
# 956 GTEX-OHPM                            GTEX-OHPM
# 957 GTEX-WI4N                            GTEX-WI4N
# 958 GTEX-WI4N                            GTEX-WI4N
# 959 GTEX-P4QS                            GTEX-P4QS
# 960 GTEX-P4PP                            GTEX-P4PP
# 961 GTEX-O5YW                            GTEX-O5YW
# 962 GTEX-O5YT                            GTEX-O5YT
# 963 GTEX-NPJ8                            GTEX-NPJ8
# 964 GTEX-WWYW                            GTEX-WWYW
# 965 GTEX-NPJ7                            GTEX-NPJ7
# 966 GTEX-P4PP                            GTEX-P4PP
#     subject_name  study   tissue    body_site
# 1   iPSCORE_2_4   ipscore ipsc_cvpc ipsc_cvpc
# 2   iPSCORE_13_3  ipscore ipsc_cvpc ipsc_cvpc
# 3   iPSCORE_8_4   ipscore ipsc_cvpc ipsc_cvpc
# 4   iPSCORE_25_1  ipscore ipsc_cvpc ipsc_cvpc
# 5   iPSCORE_116_1 ipscore ipsc_cvpc ipsc_cvpc
# 6   iPSCORE_11_3  ipscore ipsc_cvpc ipsc_cvpc
# 7   iPSCORE_13_1  ipscore ipsc_cvpc ipsc_cvpc
# 8   iPSCORE_16_3  ipscore ipsc_cvpc ipsc_cvpc
# 9   iPSCORE_29_1  ipscore ipsc_cvpc ipsc_cvpc
# 10  iPSCORE_53_1  ipscore ipsc_cvpc ipsc_cvpc
# 11  iPSCORE_9_2   ipscore ipsc_cvpc ipsc_cvpc
# 12  iPSCORE_2_11  ipscore ipsc_cvpc ipsc_cvpc
# 13  iPSCORE_101_1 ipscore ipsc_cvpc ipsc_cvpc
# 14  iPSCORE_42_1  ipscore ipsc_cvpc ipsc_cvpc
# 15  iPSCORE_8_3   ipscore ipsc_cvpc ipsc_cvpc
# 16  iPSCORE_81_1  ipscore ipsc_cvpc ipsc_cvpc
# 17  iPSCORE_18_3  ipscore ipsc_cvpc ipsc_cvpc
# 18  iPSCORE_73_1  ipscore ipsc_cvpc ipsc_cvpc
# 19  iPSCORE_19_1  ipscore ipsc_cvpc ipsc_cvpc
# 20  iPSCORE_71_1  ipscore ipsc_cvpc ipsc_cvpc
# 21  iPSCORE_9_3   ipscore ipsc_cvpc ipsc_cvpc
# 22  iPSCORE_90_1  ipscore ipsc_cvpc ipsc_cvpc
# 23  iPSCORE_9_2   ipscore ipsc_cvpc ipsc_cvpc
# 24  iPSCORE_74_1  ipscore ipsc_cvpc ipsc_cvpc
# 25  iPSCORE_99_1  ipscore ipsc_cvpc ipsc_cvpc
# 26  iPSCORE_21_3  ipscore ipsc_cvpc ipsc_cvpc
# 27  iPSCORE_11_4  ipscore ipsc_cvpc ipsc_cvpc
# 28  iPSCORE_30_2  ipscore ipsc_cvpc ipsc_cvpc
# 29  iPSCORE_2_1   ipscore ipsc_cvpc ipsc_cvpc
# 30  iPSCORE_7_2   ipscore ipsc_cvpc ipsc_cvpc
# ⋮   ⋮             ⋮       ⋮         ⋮
# 937 GTEX-WHSE     gtex    heart     heart_ventricle
# 938 GTEX-WK11     gtex    heart     heart_atrium
# 939 GTEX-WYBS     gtex    heart     heart_atrium
# 940 GTEX-P44H     gtex    arteria   arteria_aorta
# 941 GTEX-PLZ5     gtex    arteria   arteria_aorta
# 942 GTEX-X261     gtex    heart     heart_atrium
# 943 GTEX-WHWD     gtex    heart     heart_atrium
# 944 GTEX-WY7C     gtex    heart     heart_atrium
# 945 GTEX-WQUQ     gtex    heart     heart_ventricle
# 946 GTEX-P4PQ     gtex    arteria   arteria_aorta
# 947 GTEX-X4XX     gtex    heart     heart_atrium
# 948 GTEX-WWYW     gtex    heart     heart_ventricle
# 949 GTEX-WH7G     gtex    heart     heart_ventricle
# 950 GTEX-WZTO     gtex    heart     heart_ventricle
# 951 GTEX-X3Y1     gtex    heart     heart_atrium
# 952 GTEX-WHWD     gtex    heart     heart_ventricle
# 953 GTEX-WYJK     gtex    heart     heart_ventricle
# 954 GTEX-PLZ6     gtex    arteria   arteria_aorta
# 955 GTEX-WHPG     gtex    heart     heart_atrium
# 956 GTEX-OHPM     gtex    arteria   arteria_aorta
# 957 GTEX-WI4N     gtex    heart     heart_ventricle
# 958 GTEX-WI4N     gtex    heart     heart_atrium
# 959 GTEX-P4QS     gtex    arteria   arteria_aorta
# 960 GTEX-P4PP     gtex    arteria   arteria_aorta
# 961 GTEX-O5YW     gtex    arteria   arteria_coronary
# 962 GTEX-O5YT     gtex    heart     heart_ventricle
# 963 GTEX-NPJ8     gtex    arteria   arteria_coronary
# 964 GTEX-WWYW     gtex    heart     heart_atrium
# 965 GTEX-NPJ7     gtex    arteria   arteria_coronary
# 966 GTEX-P4PP     gtex    arteria   arteria_coronary

# %%
str(unique(rbp_meta$gene_name))
str(unique(rbp_meta[,c("gene_name", "cell_line")]))
# Out:
#  chr [1:148] "RBM5" "FKBP4" "UPF1" "AKAP8L" "UTP18" "PTBP1" "MATR3" "AQR" ...
# 'data.frame':	222 obs. of  2 variables:
#  $ gene_name: chr  "RBM5" "FKBP4" "UPF1" "UPF1" ...
#  $ cell_line: chr  "HepG2" "HepG2" "HepG2" "K562" ...

# %%
str(rbp_meta)
# Out:
# 'data.frame':	674 obs. of  12 variables:
#  $ gene_id  : chr  "ENSG00000003756.17_8" "ENSG00000003756.17_8" "ENSG00000003756.17_8" "ENSG00000004478.8_4" ...
#  $ gene_name: chr  "RBM5" "RBM5" "RBM5" "FKBP4" ...
#  $ id       : chr  "ENCFF980CBO" "ENCFF400CFS" "ENCFF663GBN" "ENCFF374GKD" ...
#  $ filetype : chr  "narrowPeak" "narrowPeak" "narrowPeak" "narrowPeak" ...
#  $ assembly : chr  "hg19" "hg19" "hg19" "hg19" ...
#  $ assay    : chr  "eCLIP" "eCLIP" "eCLIP" "eCLIP" ...
#  $ cell_line: chr  "HepG2" "HepG2" "HepG2" "HepG2" ...
#  $ infile   : chr  "/frazer01/home/tarthur/projects/CARDIPS/rbp_analysis/sorted_peaks/ENCFF980CBO.bed" "/frazer01/home/tarthur/projects/CARDIPS/rbp_analysis/sorted_peaks/ENCFF400CFS.bed" "/frazer01/home/tarthur/projects/CARDIPS/rbp_analysis/sorted_peaks/ENCFF663GBN.bed" "/frazer01/home/tarthur/projects/CARDIPS/rbp_analysis/sorted_peaks/ENCFF374GKD.bed" ...
#  $ beta     : num  -0.639 -0.639 -0.639 0.529 0.529 ...
#  $ pval     : num  1.52e-06 1.52e-06 1.52e-06 5.20e-06 5.20e-06 ...
#  $ qval     : num  0.0311 0.0311 0.0311 0.1059 0.1059 ...
#  $ diffexp  : logi  TRUE TRUE TRUE FALSE FALSE FALSE ...
